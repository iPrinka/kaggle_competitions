# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/jpx-tokyo-stock-exchange-prediction/stock_list.csv
# /kaggle/input/jpx-tokyo-stock-exchange-prediction/example_test_files/sample_submission.csv
# /kaggle/input/jpx-tokyo-stock-exchange-prediction/example_test_files/options.csv
# /kaggle/input/jpx-tokyo-stock-exchange-prediction/example_test_files/financials.csv
# /kaggle/input/jpx-tokyo-stock-exchange-prediction/example_test_files/secondary_stock_prices.csv
# /kaggle/input/jpx-tokyo-stock-exchange-prediction/example_test_files/trades.csv
# /kaggle/input/jpx-tokyo-stock-exchange-prediction/example_test_files/stock_prices.csv
# /kaggle/input/jpx-tokyo-stock-exchange-prediction/jpx_tokyo_market_prediction/competition.cpython-37m-x86_64-linux-gnu.so
# /kaggle/input/jpx-tokyo-stock-exchange-prediction/jpx_tokyo_market_prediction/__init__.py
# /kaggle/input/jpx-tokyo-stock-exchange-prediction/data_specifications/stock_fin_spec.csv
# /kaggle/input/jpx-tokyo-stock-exchange-prediction/data_specifications/trades_spec.csv
# ...

# %%
sample = pd.read_csv("../input/jpx-tokyo-stock-exchange-prediction/example_test_files/sample_submission.csv")
sample.head()
# Out:
#          Date  SecuritiesCode  Rank
# 0  2021-12-06            1301     0
# 1  2021-12-06            1332     1
# 2  2021-12-06            1333     2
# 3  2021-12-06            1375     3
# 4  2021-12-06            1376     4

# %%
sample.nunique()
# Out:
# Date                56
# SecuritiesCode    2000
# Rank              2000
# dtype: int64

# %% [markdown]
# What are we predicting? Rank given SecuritiesCode and Date

# %%
stock_prices = pd.read_csv("../input/jpx-tokyo-stock-exchange-prediction/train_files/stock_prices.csv")
stock_prices.head()
# Out:
#            RowId        Date  SecuritiesCode    Open    High     Low   Close  \
# 0  20170104_1301  2017-01-04            1301  2734.0  2755.0  2730.0  2742.0
# 1  20170104_1332  2017-01-04            1332   568.0   576.0   563.0   571.0
# 2  20170104_1333  2017-01-04            1333  3150.0  3210.0  3140.0  3210.0
# 3  20170104_1376  2017-01-04            1376  1510.0  1550.0  1510.0  1550.0
# 4  20170104_1377  2017-01-04            1377  3270.0  3350.0  3270.0  3330.0
#
#     Volume  AdjustmentFactor  ExpectedDividend  SupervisionFlag    Target
# 0    31400               1.0               NaN            False  0.000730
# 1  2798500               1.0               NaN            False  0.012324
# 2   270800               1.0               NaN            False  0.006154
# 3    11300               1.0               NaN            False  0.011053
# 4   150800               1.0               NaN            False  0.003026

# %%
pd.set_option('display.max_colwidth', None)

# %%
stock_price_spec = pd.read_csv("../input/jpx-tokyo-stock-exchange-prediction/data_specifications/stock_price_spec.csv")
stock_price_spec
# Out:
#               Column        Sample value     Type  Addendum  \
# 0              RowId       20170104_1301   string       NaN
# 1               Date  2017-01-04 0:00:00     date       NaN
# 2     SecuritiesCode                1301    Int64       NaN
# 3               Open                2734    float       NaN
# 4               High                2755    float       NaN
# 5                Low                2730    float       NaN
# 6              Close                2742    float       NaN
# 7             Volume               31400    Int64       NaN
# 8   AdjustmentFactor                   1    float       NaN
# 9    SupervisionFlag               FALSE  boolean       NaN
# 10  ExpectedDividend                 NaN    float       NaN
# 11            Target             0.00073    float       NaN
#
#                                                                                                                                                        Remarks
# ...

# %%
sec1301 = stock_prices[stock_prices["SecuritiesCode"]==1301].reset_index(drop=True)
sec1301.head(3)
# Out:
#            RowId        Date  SecuritiesCode    Open    High     Low   Close  \
# 0  20170104_1301  2017-01-04            1301  2734.0  2755.0  2730.0  2742.0
# 1  20170105_1301  2017-01-05            1301  2743.0  2747.0  2735.0  2738.0
# 2  20170106_1301  2017-01-06            1301  2734.0  2744.0  2720.0  2740.0
#
#    Volume  AdjustmentFactor  ExpectedDividend  SupervisionFlag    Target
# 0   31400               1.0               NaN            False  0.000730
# 1   17900               1.0               NaN            False  0.002920
# 2   19900               1.0               NaN            False -0.001092

# %% [markdown]
# Target column

# %%
sec1301["Close_t1"] = sec1301["Close"].shift(-1) #one day ahead closing price
sec1301["Close_t2"] = sec1301["Close"].shift(-2) #two days ahead closing price

sec1301["Exp_Target"] = (sec1301["Close_t2"] - sec1301["Close_t1"])/sec1301["Close_t1"]
sec1301.head(3)
# Out:
#            RowId        Date  SecuritiesCode    Open    High     Low   Close  \
# 0  20170104_1301  2017-01-04            1301  2734.0  2755.0  2730.0  2742.0
# 1  20170105_1301  2017-01-05            1301  2743.0  2747.0  2735.0  2738.0
# 2  20170106_1301  2017-01-06            1301  2734.0  2744.0  2720.0  2740.0
#
#    Volume  AdjustmentFactor  ExpectedDividend  SupervisionFlag    Target  \
# 0   31400               1.0               NaN            False  0.000730
# 1   17900               1.0               NaN            False  0.002920
# 2   19900               1.0               NaN            False -0.001092
#
#    Close_t1  Close_t2  Exp_Target
# 0    2738.0    2740.0    0.000730
# 1    2740.0    2748.0    0.002920
# 2    2748.0    2745.0   -0.001092

# %% [markdown]
# Rank based on Target

# %%
dec2_2021 = stock_prices[stock_prices["Date"] == '2021-12-02'].reset_index(drop=True)
dec2_2021
# Out:
#               RowId        Date  SecuritiesCode    Open    High     Low  \
# 0     20211202_1301  2021-12-02            1301  2949.0  2973.0  2933.0
# 1     20211202_1332  2021-12-02            1332   566.0   577.0   565.0
# 2     20211202_1333  2021-12-02            1333  2276.0  2314.0  2267.0
# 3     20211202_1375  2021-12-02            1375  1220.0  1244.0  1209.0
# 4     20211202_1376  2021-12-02            1376  1353.0  1373.0  1327.0
# ...             ...         ...             ...     ...     ...     ...
# 1995  20211202_9990  2021-12-02            9990   518.0   519.0   507.0
# 1996  20211202_9991  2021-12-02            9991   777.0   791.0   775.0
# 1997  20211202_9993  2021-12-02            9993  1672.0  1685.0  1650.0
# 1998  20211202_9994  2021-12-02            9994  2340.0  2382.0  2340.0
# 1999  20211202_9997  2021-12-02            9997   681.0   692.0   680.0
#
#        Close   Volume  AdjustmentFactor  ExpectedDividend  SupervisionFlag  \
# ...

# %%
dec2_2021["rank"] = dec2_2021["Target"].rank(ascending=False, method="first") - 1
dec2_2021 = dec2_2021.sort_values("rank").reset_index(drop=True)
dec2_2021
# Out:
#               RowId        Date  SecuritiesCode    Open    High     Low  \
# 0     20211202_4699  2021-12-02            4699  2037.0  2149.0  2037.0
# 1     20211202_4488  2021-12-02            4488  5900.0  5990.0  5690.0
# 2     20211202_8057  2021-12-02            8057  4710.0  4820.0  4615.0
# 3     20211202_9632  2021-12-02            9632  8110.0  8150.0  8000.0
# 4     20211202_6958  2021-12-02            6958   510.0   525.0   502.0
# ...             ...         ...             ...     ...     ...     ...
# 1995  20211202_4483  2021-12-02            4483  8200.0  8590.0  8180.0
# 1996  20211202_6879  2021-12-02            6879   731.0   745.0   702.0
# 1997  20211202_4168  2021-12-02            4168  4280.0  4390.0  4200.0
# 1998  20211202_3994  2021-12-02            3994  7490.0  7500.0  7060.0
# 1999  20211202_4169  2021-12-02            4169  7160.0  7870.0  7110.0
#
#        Close  Volume  AdjustmentFactor  ExpectedDividend  SupervisionFlag  \
# ...

# %% [markdown]
# When a stock or derivative is undervalued, it makes sense to buy. If it's overvalued, perhaps it's time to sell.
# Which makes sense now because if Target is + meaning, rate of change is positive, which means stock price is increasing, meaning stock is undervalued at this point, so buy. And similar logic for selling.

# %% [markdown]
# Daily Spread Return Calculation

# %% [markdown]
# Linear weights (2-1)

# %%
weights = np.linspace(start=2, stop=1, num=200)
weights
# Out:
# array([2.        , 1.99497487, 1.98994975, 1.98492462, 1.9798995 ,
#        1.97487437, 1.96984925, 1.96482412, 1.95979899, 1.95477387,
#        1.94974874, 1.94472362, 1.93969849, 1.93467337, 1.92964824,
#        1.92462312, 1.91959799, 1.91457286, 1.90954774, 1.90452261,
#        1.89949749, 1.89447236, 1.88944724, 1.88442211, 1.87939698,
#        1.87437186, 1.86934673, 1.86432161, 1.85929648, 1.85427136,
#        1.84924623, 1.84422111, 1.83919598, 1.83417085, 1.82914573,
#        1.8241206 , 1.81909548, 1.81407035, 1.80904523, 1.8040201 ,
#        1.79899497, 1.79396985, 1.78894472, 1.7839196 , 1.77889447,
#        1.77386935, 1.76884422, 1.7638191 , 1.75879397, 1.75376884,
#        1.74874372, 1.74371859, 1.73869347, 1.73366834, 1.72864322,
#        1.72361809, 1.71859296, 1.71356784, 1.70854271, 1.70351759,
#        1.69849246, 1.69346734, 1.68844221, 1.68341709, 1.67839196,
#        1.67336683, 1.66834171, 1.66331658, 1.65829146, 1.65326633,
# ...

# %%
top200 = dec2_2021.iloc[:200, :].reset_index(drop=True)
top200
# Out:
#              RowId        Date  SecuritiesCode    Open    High     Low  \
# 0    20211202_4699  2021-12-02            4699  2037.0  2149.0  2037.0
# 1    20211202_4488  2021-12-02            4488  5900.0  5990.0  5690.0
# 2    20211202_8057  2021-12-02            8057  4710.0  4820.0  4615.0
# 3    20211202_9632  2021-12-02            9632  8110.0  8150.0  8000.0
# 4    20211202_6958  2021-12-02            6958   510.0   525.0   502.0
# ..             ...         ...             ...     ...     ...     ...
# 195  20211202_6272  2021-12-02            6272  1291.0  1343.0  1291.0
# 196  20211202_6324  2021-12-02            6324  4500.0  4635.0  4400.0
# 197  20211202_2899  2021-12-02            2899  1899.0  1919.0  1880.0
# 198  20211202_2185  2021-12-02            2185  1376.0  1376.0  1355.0
# 199  20211202_4203  2021-12-02            4203  5390.0  5500.0  5310.0
#
#       Close  Volume  AdjustmentFactor  ExpectedDividend  SupervisionFlag  \
# ...

# %%
top200["weights"] = weights
top200.head()
# Out:
#            RowId        Date  SecuritiesCode    Open    High     Low   Close  \
# 0  20211202_4699  2021-12-02            4699  2037.0  2149.0  2037.0  2143.0
# 1  20211202_4488  2021-12-02            4488  5900.0  5990.0  5690.0  5700.0
# 2  20211202_8057  2021-12-02            8057  4710.0  4820.0  4615.0  4640.0
# 3  20211202_9632  2021-12-02            9632  8110.0  8150.0  8000.0  8030.0
# 4  20211202_6958  2021-12-02            6958   510.0   525.0   502.0   517.0
#
#    Volume  AdjustmentFactor  ExpectedDividend  SupervisionFlag    Target  \
# 0   31000               1.0               NaN            False  0.231481
# 1   57100               1.0               NaN            False  0.149254
# 2   29800               1.0               NaN            False  0.123110
# 3    3900               1.0               NaN            False  0.107011
# 4  639200               1.0               NaN            False  0.103113
#
#    rank   weights
# 0   0.0  2.000000
# 1   1.0  1.994975
# ...

# %%
top200["Weighted_Target"] = top200["Target"]*top200["weights"]
top200.head()
# Out:
#            RowId        Date  SecuritiesCode    Open    High     Low   Close  \
# 0  20211202_4699  2021-12-02            4699  2037.0  2149.0  2037.0  2143.0
# 1  20211202_4488  2021-12-02            4488  5900.0  5990.0  5690.0  5700.0
# 2  20211202_8057  2021-12-02            8057  4710.0  4820.0  4615.0  4640.0
# 3  20211202_9632  2021-12-02            9632  8110.0  8150.0  8000.0  8030.0
# 4  20211202_6958  2021-12-02            6958   510.0   525.0   502.0   517.0
#
#    Volume  AdjustmentFactor  ExpectedDividend  SupervisionFlag    Target  \
# 0   31000               1.0               NaN            False  0.231481
# 1   57100               1.0               NaN            False  0.149254
# 2   29800               1.0               NaN            False  0.123110
# 3    3900               1.0               NaN            False  0.107011
# 4  639200               1.0               NaN            False  0.103113
#
#    rank   weights  Weighted_Target
# ...

# %%
Sup = top200["Weighted_Target"].sum()/np.mean(weights)
Sup
# Out:
# 5.806628164587515

# %%
bottom200 = dec2_2021.iloc[-200:,:]
bottom200 = bottom200.sort_values("rank", ascending=False).reset_index(drop=True)
bottom200
# Out:
#              RowId        Date  SecuritiesCode     Open     High      Low  \
# 0    20211202_4169  2021-12-02            4169   7160.0   7870.0   7110.0
# 1    20211202_3994  2021-12-02            3994   7490.0   7500.0   7060.0
# 2    20211202_4168  2021-12-02            4168   4280.0   4390.0   4200.0
# 3    20211202_6879  2021-12-02            6879    731.0    745.0    702.0
# 4    20211202_4483  2021-12-02            4483   8200.0   8590.0   8180.0
# ..             ...         ...             ...      ...      ...      ...
# 195  20211202_4482  2021-12-02            4482    940.0    972.0    915.0
# 196  20211202_7990  2021-12-02            7990   3375.0   3390.0   3290.0
# 197  20211202_6920  2021-12-02            6920  29950.0  30360.0  29540.0
# 198  20211202_4620  2021-12-02            4620    502.0    511.0    501.0
# 199  20211202_8285  2021-12-02            8285    299.0    303.0    299.0
#
#        Close   Volume  AdjustmentFactor  ExpectedDividend  SupervisionFlag  \
# ...

# %%
bottom200["weights"] = weights
bottom200.head()
# Out:
#            RowId        Date  SecuritiesCode    Open    High     Low   Close  \
# 0  20211202_4169  2021-12-02            4169  7160.0  7870.0  7110.0  7520.0
# 1  20211202_3994  2021-12-02            3994  7490.0  7500.0  7060.0  7070.0
# 2  20211202_4168  2021-12-02            4168  4280.0  4390.0  4200.0  4335.0
# 3  20211202_6879  2021-12-02            6879   731.0   745.0   702.0   707.0
# 4  20211202_4483  2021-12-02            4483  8200.0  8590.0  8180.0  8410.0
#
#    Volume  AdjustmentFactor  ExpectedDividend  SupervisionFlag    Target  \
# 0  783000               1.0               NaN            False -0.127424
# 1  735000               1.0               NaN            False -0.094980
# 2   72600               1.0               NaN            False -0.094595
# 3  735500               1.0               NaN            False -0.087248
# 4  320300               1.0               NaN            False -0.085480
#
#      rank   weights
# 0  1999.0  2.000000
# 1  1998.0  1.994975
# ...

# %%
bottom200["Weighted_Target"] = bottom200["Target"]*bottom200["weights"]
bottom200.head()
# Out:
#            RowId        Date  SecuritiesCode    Open    High     Low   Close  \
# 0  20211202_4169  2021-12-02            4169  7160.0  7870.0  7110.0  7520.0
# 1  20211202_3994  2021-12-02            3994  7490.0  7500.0  7060.0  7070.0
# 2  20211202_4168  2021-12-02            4168  4280.0  4390.0  4200.0  4335.0
# 3  20211202_6879  2021-12-02            6879   731.0   745.0   702.0   707.0
# 4  20211202_4483  2021-12-02            4483  8200.0  8590.0  8180.0  8410.0
#
#    Volume  AdjustmentFactor  ExpectedDividend  SupervisionFlag    Target  \
# 0  783000               1.0               NaN            False -0.127424
# 1  735000               1.0               NaN            False -0.094980
# 2   72600               1.0               NaN            False -0.094595
# 3  735500               1.0               NaN            False -0.087248
# 4  320300               1.0               NaN            False -0.085480
#
#      rank   weights  Weighted_Target
# ...

# %%
Sdown = bottom200["Weighted_Target"].sum()/np.mean(weights)
Sdown
# Out:
# -9.10891259103055

# %%
daily_spread_return = Sup - Sdown
daily_spread_return
# Out:
# 14.915540755618066
